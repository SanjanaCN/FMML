# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-18 05:01:45--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   271MB/s    in 0.3s
#
# 2022-06-18 05:01:47 (271 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22862  1709.05276v1  We compare two statistical models of three bin...  stat
# 19030   1301.7359v1  This paper addresses the problem of merging un...    cs
# 17225  1709.05631v2  Word discovery is the task of extracting words...    cs
# 6210   1609.05772v1  This paper considers a restriction to non-nega...  stat
# 23393   1201.3972v1  In this study we investigate the fast image fi...    cs
# ...             ...                                                ...   ...
# 31930   1301.2012v1  This paper is concerned with learning binary c...    cs
# 21887   1408.0145v2  This contribution deals with the generalized s...  stat
# 5069   1802.00332v1  Tactical driving decision making is crucial fo...    cs
# 6334   1611.04499v2  One of the main challenges of deep learning me...  stat
# 25254  1506.08815v1  Sometimes a simple and fast algorithm is requi...    cs
#
#                                                    title  year  \
# 22862      Mixtures and products in two graphical models  2017
# 19030  Merging Uncertain Knowledge Bases in a Possibi...  2013
# 17225  Unwritten Languages Demand Attention Too! Word...  2017
# 6210                     Stochastic Matrix Factorization  2016
# 23393  A Novel Approach to Fast Image Filtering Algor...  2012
# ...                                                  ...   ...
# 31930            Error Correction in Learning using SVMs  2013
# 21887  A convergence and asymptotic analysis of the g...  2014
# 5069   Elements of Effective Deep Reinforcement Learn...  2018
# 6334     Post Training in Deep Learning with Last Kernel  2016
# 25254  Tracking Direction of Human Movement - An Effi...  2015
#
#                                                 keywords
# 22862  [statistical, variables, restricted, boltzmann...
# 19030  [addresses, uncertain, information, framework,...
# 17225  [discovery, extracting, unsegmented, realistic...
# 6210   [considers, restriction, factorization, stocha...
# 23393  [investigate, filtering, algorithm, algorithm,...
# ...                                                  ...
# 31930  [concerned, classifiers, adversarial, introduc...
# 21887  [contribution, generalized, symmetric, algorit...
# 5069   [autonomous, attracted, considerable, practica...
# 6334   [challenges, appropriate, particular, addition...
# 25254  [sometimes, algorithm, controlled, environment...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22862    [statistical, variables, restricted, boltzmann...
# 19030    [addresses, uncertain, information, framework,...
# 17225    [discovery, extracting, unsegmented, realistic...
# 6210     [considers, restriction, factorization, stocha...
# 23393    [investigate, filtering, algorithm, algorithm,...
#                                ...
# 12027    [statistical, statistical, guarantees, depende...
# 26054    [minimization, components, different, componen...
# 13393    [dissipation, sequential, increased, successiv...
# 5081     [conditioned, methodology, controlling, lipsch...
# 22175    [nonparametric, extension, regression, nonline...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8750 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a6a719bd-9e17-40f4-9bb6-303ddbe5e4bb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6a719bd-9e17-40f4-9bb6-303ddbe5e4bb")) {                    Plotly.newPlot(                        "a6a719bd-9e17-40f4-9bb6-303ddbe5e4bb",                        [{"x":["distributions","estimates","boltzmann","variables","algebraic","statistical","expressions","probability","extensions","inequalities","different","restricted","parametrizations","represent","likelihood","description","graphical","described","information","extension","addresses","combination","syntactic","framework","uncertain","knowledge","semantics","possibilistic","available","realistic","vocabulary","bilingual","annotations","attention","perspective","unsegmented","alignments","discovery","scenarios","translation","extracting","sentences","languages","advantage","supervision","generating","investigate","nonparametric","illustrated","restriction","stochastic","analyzing","abstracts","parameters","estimator","necessary","factorization","characterizes","consistent","economics","sufficient","retrieving","unstructured","conditions","considers","recursion","comparison","developed","algorithm","processing","computation","reduction","filtering","applications","increases","significantly","structural","converging","outperforming","solutions","exploration","experiments","demonstrate","extensive","numerical","cooperation","exploitation","recognized","satisfactory","heterogeneous","diversity","evolution","optimization","performance","microscopic","particles","proportion","applicability","facilitate","objective","algorithms","compatible","converges","approximation","surprisingly","programming","application","mathematical","evaluation","techniques","automatically","workloads","representations","synthetic","predicting","summarization","approaches","specialized","recommendation","unrelated","classifier","recommended","foundation","selection","execution","engineering","generalized","prediction","outperform","optimized","requiring","analytics","including","assignment","warehouse","heuristics","suggested","specifically","simulated","annealing","necessarily","experiment","frequency","retrieval","correlated","positively","assignments","constraints","clustering","projected","particular","identified","efficient","projections","estimators","important","practical","quantizing","quantization","sublinear","preferable","candidate","effective","estimation","similarities","approximate","experimental","typically","similarity","therefore","combining","nonlinear","independent","efficiently","conditionally","traditional","flexibility","conjunctions","correspond","induction","overlapping","extraction","additional","granularity","automated","tractability","structures","undirected","principle","conditional","constructing","providing","modifications","relational","magnitude","probabilities","arbitrary","employing","contained","encompass"],"y":[133,73,12,130,16,172,40,172,36,6,785,47,0,136,61,64,41,69,685,70,52,119,57,562,29,351,99,5,317,61,37,14,55,178,65,3,9,54,89,115,56,67,100,81,45,111,133,21,20,9,121,60,4,255,30,60,38,12,84,6,66,9,22,146,30,5,131,227,847,305,131,99,61,422,55,273,82,8,34,153,57,593,545,165,77,10,15,17,11,34,54,70,334,922,4,9,8,42,43,174,579,18,20,115,33,107,273,59,259,377,173,3,230,147,90,34,442,16,34,7,139,2,16,149,32,59,75,214,81,59,39,17,235,36,3,39,16,174,65,12,22,90,66,99,32,5,8,147,135,15,256,35,407,24,14,360,121,4,25,10,10,43,275,184,35,112,390,100,141,131,98,52,134,143,5,171,39,4,27,18,23,114,113,10,107,6,133,14,54,79,38,90,20,27,52,58,80,44,19,5],"type":"bar"},{"x":["distributions","estimates","boltzmann","variables","algebraic","statistical","expressions","probability","extensions","inequal ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8266666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Beyond</span> <span style=''>Parity</span> <span style=''>Fairness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Objectives</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Collaborative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Filtering</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>fairness</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collaborative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommender</span> <span style=''>systems</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discrimination</span> <span style=''>that</span> <span style=''>exists</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>historical</span> <span style=''>data</span> <span style=''>Biased</span> <span style=''>data</span> <span style=''>can</span> <span style=''>lead</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collaborative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>make</span> <span style=''>unfair</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>for</span> <span style=''>users</span> <span style=''>from</span> <span style=''>minority</span> <span style=''>groups</span> <span style=''>We</span> <span style=''>identify</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>insufficiency</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>fairness</span> <span style=''>metrics</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>four</span> <span style=''>new</span> <span style=''>metrics</span> <span style=''>that</span> <span style=''>address</span> <span style='background-color:rgba(0, 255, 0, 0.340734415029889);'>different</span> <span style=''>forms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unfairness</span> <span style=''>These</span> <span style=''>fairness</span> <span style=''>metrics</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimized</span> <span style=''>by</span> <span style=''>adding</span> <span style=''>fairness</span> <span style=''>terms</span> <span style=''>to</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>and</span> <span style=''>real</span> <span style=''>data</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>new</span> <span style=''>metrics</span> <span style=''>can</span> <span style=''>better</span> <span style=''>measure</span> <span style=''>fairness</span> <span style=''>than</span> <span style=''>the</span> <span style=''>baseline</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style=''>fairness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objectives</span> <span style='background-color:rgba(0, 255, 0, 0.4110429447852761);'>effectively</span> <span style=''>help</span> <span style=''>reduce</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unfairness</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distribution</span> <span style=''>To</span> <span style=''>Real</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>to</span> <span style=''>real</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>where</span> <span style=''>one</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>regress</span> <span style=''>a</span> <span style=''>mapping</span> <span style=''>f</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>input</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style=''>Pin</span> <span style=''>mathcalI</span> <span style=''>(for</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>mathcalI)</span> <span style=''>and</span> <span style=''>outputs</span> <span style=''>a</span> <span style=''>real</span> <span style=''>valued</span> <span style=''>response</span> <span style=''>Yf(P)</span> <span style=''>epsilon</span> <span style=''>This</span> <span style=''>setting</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>a</span> <span style=''>Kernel</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>and</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>rate</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>However</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Kernel</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>scales</span> <span style=''>as</span> <span style=''>Omega(N)</span> <span style=''>This</span> <span style=''>causes</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>where</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>data</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>for</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>risk</span> <span style=''>but</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>cost</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>becomes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>infeasible</span> <span style=''>when</span> <span style=''>the</span> <span style=''>data ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3696969696969697);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.30352045670789723);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Bottleneck</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.30352045670789723);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bottleneck</span> <span style=''>IB</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4177215189873417);'>extracting</span> <span style='background-color:rgba(0, 255, 0, 0.30352045670789723);'>information</span> <span style=''>in</span> <span style=''>some</span> <span style=''>input</span> <span style=''>random</span> <span style=''>variable</span> <span style=''>that</span> <span style=''>is</span> <span style=''>relevant</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.340734415029889);'>different</span> <span style=''>output</span> <span style=''>random</span> <span style=''>variable</span> <span style=''>IB</span> <span style=''>works</span> <span style=''>by</span> <span style=''>encoding</span> <span style=''>the</span> <span style=''>input</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>bottleneck</span> <span style=''>variable</span> <span style=''>from</span> <span style=''>which</span> <span style=''>the</span> <span style=''>output</span> <span style=''>can</span> <span style=''>then</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>decoded</span> <span style=''>IB</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>mainly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>two</span> <span style=''>limited</span> <span style=''>cases</span> <span style=''>(1)</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3564356435643565);'>variables</span> <span style=''>with</span> <span style=''>small</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>and</span> <span style=''>(2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3564356435643565);'>variables</span> <span style=''>that</span> <span style=''>are</span> <span style=''>jointly</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style=''>(in</span> <span style=''>which</span> <span style=''>case</span> <span style=''>the</span> <span style=''>encoding</span> <span style=''>and</span> <span style=''>decoding</span> <span style=''>maps</span> <span style=''>are</span> <span style=''>linear)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>IB</span> <span style=''>in</span> <span style=''>more</span> <span style=''>general</span> <span style=''>domains</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>discrete</span> <span style=''>or</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Standardizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Interestingness</span> <span style=''>Measures</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Association</span> <span style=''>Rules</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Interestingness</span> <span style=''>measures</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>prune</span> <span style=''>or</span> <span style=''>select</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>rules</span> <span style=''>A</span> <span style=''>given</span> <span style=''>value</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interestingness</span> <span style=''>measure</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpreted</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>overall</span> <span style=''>range</span> <span style=''>of</span> <span style=''>the</span> <span style=''>values</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interestingness</span> <span style=''>measure</span> <span style=''>can</span> <span style=''>take</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>rules</span> <span style=''>restrict</span> <span style=''>the</span> <span style=''>values</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interestingness</span> <span style=''>measure</span> <span style=''>can</span> <span style=''>achieve</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style=''>measure</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>standardized</span> <span style=''>to</span> <span style=''>take</span> <span style=''>this</span> <span style=''>into</span> <span style=''>account</span> <span style=''>but</span> <span style=''>this</span> <span style=''>has</span> <span style=''>only</span> <span style=''>been</span> <span style=''>done</span> <span style=''>for</span> <span style=''>one</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interestingness</span> <span style=''>measure</span> <span style=''>to</span> <span style=''>date</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>lift</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Standardization</span> <span style=''>provides</span> <span style=''>greater</span> <span style=''>insight</span> <span style=''>than</span> <span style=''>the</span> <span style=''>raw</span> <span style=''>value</span> <span style=''>and</span> <span style=''>may</span> <span style=''>even</span> <span style=''>alter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>researchers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perception</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>We</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>standardized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analogues</span> <span style=''>of</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interestingness</span> <span style=''>measures</span> <span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1263498920086393)
# 	representation (0.13930885529157666)
# 	experimental (0.14038876889848811)
# 	segmentation (0.08063354931605471)
# 	architecture (0.09503239740820735)
# 	information (0.24658027357811374)
# 	detection (0.12419006479481641)
# 	convolutional (0.1396688264938805)
# 	different (0.28257739380849534)
# 	recognition (0.13390928725701945)
#
# Some Statistics words are:
# 	algorithm (0.38724035608308605)
# 	variables (0.13550939663699307)
# 	statistical (0.15182987141444115)
# 	stochastic (0.14292779426310584)
# 	theoretical (0.1533135509396637)
# 	distribution (0.18545994065281898)
# 	estimation (0.1785361028684471)
# 	inference (0.19881305637982197)
# 	dimensional (0.19584569732937684)
# 	regression (0.1894164193867458)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="06cfd546-3c36-4ff1-9f05-8dbd322e4267" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06cfd546-3c36-4ff1-9f05-8dbd322e4267")) {                    Plotly.newPlot(                        "06cfd546-3c36-4ff1-9f05-8dbd322e4267",                        [{"x":["distributions","estimates","boltzmann","variables","algebraic","statistical","expressions","probability","extensions","inequalities","different","restricted","parametrizations","represent","likelihood","description","graphical","described","information","extension","addresses","combination","syntactic","framework","uncertain","knowledge","semantics","possibilistic","available","realistic","vocabulary","bilingual","annotations","attention","perspective","unsegmented","alignments","discovery","scenarios","translation","extracting","sentences","languages","advantage","supervision","generating","investigate","nonparametric","illustrated","restriction","stochastic","analyzing","abstracts","parameters","estimator","necessary","factorization","characterizes","consistent","economics","sufficient","retrieving","unstructured","conditions","considers","recursion","comparison","developed","algorithm","processing","computation","reduction","filtering","applications","increases","significantly","structural","converging","outperforming","solutions","exploration","experiments","demonstrate","extensive","numerical","cooperation","exploitation","recognized","satisfactory","heterogeneous","diversity","evolution","optimization","performance","microscopic","particles","proportion","applicability","facilitate","objective","algorithms","compatible","converges","approximation","surprisingly","programming","application","mathematical","evaluation","techniques","automatically","workloads","representations","synthetic","predicting","summarization","approaches","specialized","recommendation","unrelated","classifier","recommended","foundation","selection","execution","engineering","generalized","prediction","outperform","optimized","requiring","analytics","including","assignment","warehouse","heuristics","suggested","specifically","simulated","annealing","necessarily","experiment","frequency","retrieval","correlated","positively","assignments","constraints","clustering","projected","particular","identified","efficient","projections","estimators","important","practical","quantizing","quantization","sublinear","preferable","candidate","effective","estimation","similarities","approximate","experimental","typically","similarity","therefore","combining","nonlinear","independent","efficiently","conditionally","traditional","flexibility","conjunctions","correspond","induction","overlapping","extraction","additional","granularity","automated","tractability","structures","undirected","principle","conditional","constructing","providing","modifications","relational","magnitude","probabilities","arbitrary","employing","contained","encompass","establishes","heisenberg","operating","proportional","challenges","scattering","exponential","linearity","guaranteed","desirable","informative","corresponding","extractors","extractor","conservation","generated","constructions","polynomially","formidable","propagated","propagation","convolutional","understand","computational","accomplished","calculations","calculation","architectures","convolution","accelerate","exploiting","multiplication","improvements","rectifier","objectives","quadratic","analogous","conjecture","convergence","parameter","operation","distributed","sometimes","diffusion","manifolds","introduce","artificially","laplacian","constructed","strengths","dimensional","observations","generative","highlights","directional","embedding","euclidean","estimating","retaining","th ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parametrizations
# 	sparsities
# 	coregionalization
# 	circumvents
# 	stationarity
# 	minimised
# 	abandonment
# 	personalizing
# 	independences
# 	confounders
# 	photovoltaic
# 	emphdirectly
# 	nonstationary
# 	deterministically
# 	regularizations
# 	framelets
# 	aerodynamic
# 	parameterize
# 	lightspeed
# 	nonstationarity
# Some words which never appear in Statistics papers:
# 	syntactic
# 	possibilistic
# 	bilingual
# 	unsegmented
# 	warehouse
# 	conjunctions
# 	identifiers
# 	culminating
# 	displacements
# 	landmarks
# 	geographic
# 	obligatory
# 	satisfiability
# 	accordance
# 	locomotion
# 	endeavour
# 	primitive
# 	enhancements
# 	celebrity
# 	treebanks

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0905213709552804e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78
